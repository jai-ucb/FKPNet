# %% [markdown]
# # GPU Monitor

# %%
#https://developer.nvidia.com/blog/profiling-and-optimizing-deep-neural-networks-with-dlprof-and-pyprof/
#nvidia-smi
#nvidia-smi dmon

# %% [markdown]
# ## Import Libs

# %%
# This tells matplotlib not to try opening a new window for each plot.
# %matplotlib inline

import os
####*IMPORANT*: Have to do this line *before* importing tensorflow
os.environ['PYTHONHASHSEED']=str(1)

# General libraries.
import re
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle

from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

import cv2
from math import sin, cos, pi
from time import strftime
from datetime import datetime

# %%
train_data = pd.read_csv('data/training.csv') 
test_data = pd.read_csv('data/test.csv') 
Id_data = pd.read_csv('data/IdLookupTable.csv')

# %% [markdown]
# # MODEL EXAMPLE
# https://www.tensorflow.org/tutorials/images/cnn

# %%
from tensorflow import keras
from keras.layers import Conv2D,Dropout,Dense,Flatten
from keras.models import Sequential
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential, Model
from keras.layers import Activation, Convolution2D, MaxPooling2D, BatchNormalization, Flatten, Dense, Dropout, Conv2D,MaxPool2D, ZeroPadding2D
import random
import tensorflow as tf

# %%
epochs = 150
def reset_random_seeds():
    os.environ['PYTHONHASHSEED']=str(1)
    tf.random.set_seed(1)
    np.random.seed(1)
    random.seed(1)

#make some random data
reset_random_seeds()

# %%
model = Sequential()

#Block 1
model.add(Convolution2D(32, (3,3), padding='same', use_bias=False, input_shape=(96,96,1)))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(32, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

#Block 2
model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(64, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

# Block 3
model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(96, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

#Block 4
model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(128, (3,3),padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

#Block 5
model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(256, (3,3),padding='same',use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))

#Block 6
model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Convolution2D(512, (3,3), padding='same', use_bias=False))
model.add(LeakyReLU(alpha = 0.1))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(30))
model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 96, 96, 32)        288
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 96, 96, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        9216
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 96, 96, 32)        0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 96, 96, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 48, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 48, 48, 64)        18432
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 48, 48, 64)        36864
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 48, 48, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 48, 48, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 24, 24, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 24, 24, 96)        55296
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 24, 24, 96)        384
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 24, 24, 96)        82944
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 24, 24, 96)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 24, 24, 96)        384
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 96)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 12, 12, 128)       110592
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 12, 12, 128)       147456
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 12, 12, 128)       0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 6, 6, 256)         294912
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 6, 6, 256)         589824
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 6, 6, 256)         0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 6, 6, 256)         1024
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 3, 3, 256)         0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 3, 3, 512)         1179648
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 3, 3, 512)         2359296
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 3, 3, 512)         2048
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               2359808
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 30)                15390
# =================================================================
# Total params: 7,268,670
# Trainable params: 7,264,318
# Non-trainable params: 4,352
# _________________________________________________________________
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
model.compile(optimizer='adam',loss='mean_squared_error',metrics=['mae','accuracy'])

# %%
train_data = pd.read_csv('data/training.csv')

images = []
y_train = []

print(len(train_data))
train_data = train_data.fillna(method = 'ffill')
for idx, sample in train_data.iterrows():
    image = np.array(sample['Image'].split(' '), dtype=int)
    image = np.reshape(image, (96,96,1))
    images.append(image)
X_train = np.array(images)
# Out:
# 7049

# %%
training = train_data.drop('Image',axis = 1)

y_train = []
for idx, sample in training.iterrows():
    y = training.iloc[idx,:]
    y_train.append(y)    
y_train = np.array(y_train,dtype = 'float')

# %%
start_time = datetime.now()
history = model.fit(X_train,y_train,epochs = epochs,batch_size = 450,validation_split = 0.2)
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Epoch 1/150
#  2/13 [===>..........................] - ETA: 2s - loss: 2348.9858 - mae: 44.9870 - accuracy: 0.1044WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1412s vs `on_train_batch_end` time: 0.2362s). Check your callbacks.
# 13/13 [==============================] - 7s 511ms/step - loss: 580.3329 - mae: 17.1080 - accuracy: 0.2625 - val_loss: 1467.5603 - val_mae: 35.7967 - val_accuracy: 0.6816
# Epoch 2/150
# 13/13 [==============================] - 5s 385ms/step - loss: 47.7217 - mae: 5.4430 - accuracy: 0.3325 - val_loss: 513.9916 - val_mae: 21.0221 - val_accuracy: 0.6872
# Epoch 3/150
# 13/13 [==============================] - 5s 392ms/step - loss: 33.2290 - mae: 4.4946 - accuracy: 0.3412 - val_loss: 345.3097 - val_mae: 16.9957 - val_accuracy: 0.6766
# Epoch 4/150
# 13/13 [==============================] - 5s 402ms/step - loss: 28.2029 - mae: 4.1070 - accuracy: 0.3775 - val_loss: 184.2880 - val_mae: 12.4215 - val_accuracy: 0.6184
# Epoch 5/150
# 13/13 [==============================] - 5s 391ms/step - loss: 25.7507 - mae: 3.9211 - accuracy: 0.3939 - val_loss: 139.1663 - val_mae: 10.7348 - val_accuracy: 0.6872
# Epoch 6/150
# 13/13 [==============================] - 5s 385ms/step - loss: 24.5240 - mae: 3.8152 - accuracy: 0.4033 - val_loss: 82.8066 - val_mae: 8.1949 - val_accuracy: 0.6872
# Epoch 7/150
# 13/13 [==============================] - 5s 388ms/step - loss: 23.3164 - mae: 3.7173 - accuracy: 0.4111 - val_loss: 71.4257 - val_mae: 7.5775 - val_accuracy: 0.6872
# Epoch 8/150
# 13/13 [==============================] - 5s 391ms/step - loss: 22.3687 - mae: 3.6353 - accuracy: 0.4151 - val_loss: 79.5705 - val_mae: 8.0162 - val_accuracy: 0.6872
# Epoch 9/150
# 13/13 [==============================] - 5s 406ms/step - loss: 21.3786 - mae: 3.5461 - accuracy: 0.4288 - val_loss: 67.2481 - val_mae: 7.3233 - val_accuracy: 0.6766
# Epoch 10/150
# 13/13 [==============================] - 5s 413ms/step - loss: 20.5092 - mae: 3.4676 - accuracy: 0.4341 - val_loss: 70.2677 - val_mae: 7.5024 - val_accuracy: 0.6872
# Epoch 11/150
# 13/13 [==============================] - 5s 395ms/step - loss: 19.3732 - mae: 3.3644 - accuracy: 0.4492 - val_loss: 55.6519 - val_mae: 6.6817 - val_accuracy: 0.6511
# Epoch 12/150
# 13/13 [==============================] - 5s 386ms/step - loss: 18.7557 - mae: 3.3076 - accuracy: 0.4646 - val_loss: 47.3342 - val_mae: 6.1346 - val_accuracy: 0.6681
# Epoch 13/150
# 13/13 [==============================] - 5s 385ms/step - loss: 18.0382 - mae: 3.2327 - accuracy: 0.4971 - val_loss: 51.4595 - val_mae: 6.3700 - val_accuracy: 0.6879
# Epoch 14/150
# 13/13 [==============================] - 5s 386ms/step - loss: 17.3750 - mae: 3.1726 - accuracy: 0.5217 - val_loss: 38.6509 - val_mae: 5.4955 - val_accuracy: 0.6901
# Epoch 15/150
# 13/13 [==============================] - 5s 389ms/step - loss: 16.6991 - mae: 3.1106 - accuracy: 0.5285 - val_loss: 35.9662 - val_mae: 5.2169 - val_accuracy: 0.6894
# Epoch 16/150
# 13/13 [==============================] - 5s 385ms/step - loss: 16.2608 - mae: 3.0674 - accuracy: 0.5474 - val_loss: 29.3342 - val_mae: 4.6975 - val_accuracy: 0.6922
# Epoch 17/150
# 13/13 [==============================] - 5s 388ms/step - loss: 15.6878 - mae: 3.0040 - accuracy: 0.5677 - val_loss: 28.9464 - val_mae: 4.6748 - val_accuracy: 0.6936
# Epoch 18/150
# 13/13 [==============================] - 5s 388ms/step - loss: 15.0935 - mae: 2.9507 - accuracy: 0.5737 - val_loss: 31.7506 - val_mae: 4.9227 - val_accuracy: 0.6986
# Epoch 19/150
# 13/13 [==============================] - 5s 390ms/step - loss: 14.8408 - mae: 2.9189 - accuracy: 0.5888 - val_loss: 27.1344 - val_mae: 4.4873 - val_accuracy: 0.7099
# Epoch 20/150
# 13/13 [==============================] - 5s 388ms/step - loss: 14.3354 - mae: 2.8713 - accuracy: 0.5943 - val_loss: 32.5914 - val_mae: 4.9989 - val_accuracy: 0.7043
# Epoch 21/150
# 13/13 [==============================] - 5s 387ms/step - loss: 13.8491 - mae: 2.8246 - accuracy: 0.6154 - val_loss: 24.8612 - val_mae: 4.2731 - val_accuracy: 0.6929
# Epoch 22/150
# 13/13 [==============================] - 5s 388ms/step - loss: 13.2634 - mae: 2.7558 - accuracy: 0.6079 - val_loss: 27.2205 - val_mae: 4.4870 - val_accuracy: 0.7071
# Epoch 23/150
# 13/13 [==============================] - 5s 388ms/step - loss: 13.0476 - mae: 2.7415 - accuracy: 0.6288 - val_loss: 25.0406 - val_mae: 4.3041 - val_accuracy: 0.7078
# Epoch 24/150
# 13/13 [==============================] - 5s 388ms/step - loss: 13.1000 - mae: 2.7484 - accuracy: 0.6381 - val_loss: 23.2284 - val_mae: 4.1025 - val_accuracy: 0.7113
# Epoch 25/150
# 13/13 [==============================] - 5s 388ms/step - loss: 13.1137 - mae: 2.7531 - accuracy: 0.6430 - val_loss: 10.3301 - val_mae: 2.4815 - val_accuracy: 0.7028
# Epoch 26/150
# 13/13 [==============================] - 5s 402ms/step - loss: 12.1342 - mae: 2.6463 - accuracy: 0.6382 - val_loss: 19.4596 - val_mae: 3.5266 - val_accuracy: 0.7355
# Epoch 27/150
# 13/13 [==============================] - 5s 399ms/step - loss: 11.4833 - mae: 2.5719 - accuracy: 0.6593 - val_loss: 12.3983 - val_mae: 2.8072 - val_accuracy: 0.7064
# Epoch 28/150
# 13/13 [==============================] - 5s 388ms/step - loss: 11.5815 - mae: 2.5908 - accuracy: 0.6602 - val_loss: 12.7101 - val_mae: 2.8289 - val_accuracy: 0.7113
# Epoch 29/150
# 13/13 [==============================] - 5s 394ms/step - loss: 10.9659 - mae: 2.5140 - accuracy: 0.6569 - val_loss: 13.6112 - val_mae: 2.9669 - val_accuracy: 0.7057
# Epoch 30/150
# 13/13 [==============================] - 5s 397ms/step - loss: 11.6576 - mae: 2.6040 - accuracy: 0.6611 - val_loss: 4.6057 - val_mae: 1.2862 - val_accuracy: 0.6929
# Epoch 31/150
# 13/13 [==============================] - 5s 402ms/step - loss: 10.9163 - mae: 2.5172 - accuracy: 0.6636 - val_loss: 15.7970 - val_mae: 3.2533 - val_accuracy: 0.6972
# Epoch 32/150
# 13/13 [==============================] - 5s 396ms/step - loss: 10.9173 - mae: 2.5208 - accuracy: 0.6705 - val_loss: 8.0337 - val_mae: 2.1155 - val_accuracy: 0.7142
# Epoch 33/150
# 13/13 [==============================] - 5s 386ms/step - loss: 10.7595 - mae: 2.5002 - accuracy: 0.6732 - val_loss: 3.4481 - val_mae: 1.0265 - val_accuracy: 0.7028
# Epoch 34/150
# 13/13 [==============================] - 5s 386ms/step - loss: 10.4232 - mae: 2.4655 - accuracy: 0.6835 - val_loss: 5.8788 - val_mae: 1.6400 - val_accuracy: 0.6965
# Epoch 35/150
# 13/13 [==============================] - 5s 390ms/step - loss: 10.1284 - mae: 2.4294 - accuracy: 0.6792 - val_loss: 12.5775 - val_mae: 2.8824 - val_accuracy: 0.7113
# Epoch 36/150
# 13/13 [==============================] - 5s 387ms/step - loss: 10.0599 - mae: 2.4206 - accuracy: 0.6852 - val_loss: 3.5041 - val_mae: 1.0139 - val_accuracy: 0.6972
# Epoch 37/150
# 13/13 [==============================] - 5s 389ms/step - loss: 9.9597 - mae: 2.4092 - accuracy: 0.6939 - val_loss: 3.7296 - val_mae: 1.1928 - val_accuracy: 0.7234
# Epoch 38/150
# 13/13 [==============================] - 5s 389ms/step - loss: 9.6587 - mae: 2.3750 - accuracy: 0.7017 - val_loss: 3.7181 - val_mae: 1.2518 - val_accuracy: 0.6950
# Epoch 39/150
# 13/13 [==============================] - 5s 391ms/step - loss: 9.2790 - mae: 2.3223 - accuracy: 0.6930 - val_loss: 4.0891 - val_mae: 1.1898 - val_accuracy: 0.7418
# Epoch 40/150
# 13/13 [==============================] - 5s 388ms/step - loss: 8.7777 - mae: 2.2630 - accuracy: 0.7021 - val_loss: 6.3083 - val_mae: 1.7274 - val_accuracy: 0.7199
# Epoch 41/150
# 13/13 [==============================] - 5s 388ms/step - loss: 8.4978 - mae: 2.2271 - accuracy: 0.7134 - val_loss: 8.4956 - val_mae: 2.2754 - val_accuracy: 0.7191
# Epoch 42/150
# 13/13 [==============================] - 5s 387ms/step - loss: 8.3297 - mae: 2.2033 - accuracy: 0.7164 - val_loss: 5.6016 - val_mae: 1.6018 - val_accuracy: 0.7340
# Epoch 43/150
# 13/13 [==============================] - 5s 387ms/step - loss: 8.2624 - mae: 2.1956 - accuracy: 0.7294 - val_loss: 6.6890 - val_mae: 1.9306 - val_accuracy: 0.7319
# Epoch 44/150
# 13/13 [==============================] - 5s 390ms/step - loss: 7.6742 - mae: 2.1161 - accuracy: 0.7306 - val_loss: 6.6704 - val_mae: 1.9120 - val_accuracy: 0.7355
# Epoch 45/150
# 13/13 [==============================] - 5s 394ms/step - loss: 7.6575 - mae: 2.1117 - accuracy: 0.7255 - val_loss: 10.2672 - val_mae: 2.5556 - val_accuracy: 0.6986
# Epoch 46/150
# 13/13 [==============================] - 5s 388ms/step - loss: 8.8910 - mae: 2.2917 - accuracy: 0.7377 - val_loss: 3.6162 - val_mae: 1.0689 - val_accuracy: 0.7220
# Epoch 47/150
# 13/13 [==============================] - 5s 387ms/step - loss: 7.2176 - mae: 2.0578 - accuracy: 0.7269 - val_loss: 4.3155 - val_mae: 1.2682 - val_accuracy: 0.7191
# Epoch 48/150
# 13/13 [==============================] - 5s 387ms/step - loss: 7.5707 - mae: 2.1124 - accuracy: 0.7383 - val_loss: 7.9880 - val_mae: 2.1384 - val_accuracy: 0.7234
# Epoch 49/150
# 13/13 [==============================] - 5s 389ms/step - loss: 8.6290 - mae: 2.2551 - accuracy: 0.7482 - val_loss: 5.3118 - val_mae: 1.6356 - val_accuracy: 0.7184
# Epoch 50/150
# 13/13 [==============================] - 5s 388ms/step - loss: 7.3355 - mae: 2.0728 - accuracy: 0.7372 - val_loss: 2.9829 - val_mae: 0.9672 - val_accuracy: 0.7319
# Epoch 51/150
# 13/13 [==============================] - 5s 397ms/step - loss: 7.9685 - mae: 2.1655 - accuracy: 0.7411 - val_loss: 4.1776 - val_mae: 1.3010 - val_accuracy: 0.7255
# Epoch 52/150
# 13/13 [==============================] - 5s 398ms/step - loss: 9.2434 - mae: 2.3416 - accuracy: 0.7523 - val_loss: 3.1349 - val_mae: 1.1168 - val_accuracy: 0.7645
# Epoch 53/150
# 13/13 [==============================] - 5s 395ms/step - loss: 7.4354 - mae: 2.1022 - accuracy: 0.7528 - val_loss: 3.6410 - val_mae: 1.1340 - val_accuracy: 0.7596
# Epoch 54/150
# 13/13 [==============================] - 5s 390ms/step - loss: 6.5534 - mae: 1.9612 - accuracy: 0.7478 - val_loss: 3.7746 - val_mae: 1.1661 - val_accuracy: 0.7397
# Epoch 55/150
# 13/13 [==============================] - 5s 405ms/step - loss: 7.0858 - mae: 2.0432 - accuracy: 0.7553 - val_loss: 7.2078 - val_mae: 2.1987 - val_accuracy: 0.7454
# Epoch 56/150
# 13/13 [==============================] - 5s 410ms/step - loss: 8.0854 - mae: 2.1890 - accuracy: 0.7608 - val_loss: 3.1357 - val_mae: 1.0800 - val_accuracy: 0.7638
# Epoch 57/150
# 13/13 [==============================] - 5s 397ms/step - loss: 6.7209 - mae: 1.9926 - accuracy: 0.7599 - val_loss: 2.6116 - val_mae: 0.8788 - val_accuracy: 0.7610
# Epoch 58/150
# 13/13 [==============================] - 5s 390ms/step - loss: 6.1945 - mae: 1.9086 - accuracy: 0.7682 - val_loss: 2.6284 - val_mae: 0.8556 - val_accuracy: 0.7610
# Epoch 59/150
# 13/13 [==============================] - 5s 387ms/step - loss: 6.0065 - mae: 1.8803 - accuracy: 0.7684 - val_loss: 3.0520 - val_mae: 0.9860 - val_accuracy: 0.7596
# Epoch 60/150
# 13/13 [==============================] - 5s 397ms/step - loss: 6.6501 - mae: 1.9826 - accuracy: 0.7627 - val_loss: 3.8837 - val_mae: 1.4055 - val_accuracy: 0.7319
# Epoch 61/150
# 13/13 [==============================] - 5s 398ms/step - loss: 7.3162 - mae: 2.0858 - accuracy: 0.7664 - val_loss: 2.4191 - val_mae: 0.7940 - val_accuracy: 0.7759
# Epoch 62/150
# 13/13 [==============================] - 5s 400ms/step - loss: 6.6155 - mae: 1.9768 - accuracy: 0.7852 - val_loss: 2.7415 - val_mae: 0.8869 - val_accuracy: 0.7560
# Epoch 63/150
# 13/13 [==============================] - 5s 398ms/step - loss: 6.2414 - mae: 1.9185 - accuracy: 0.7753 - val_loss: 2.7232 - val_mae: 0.8810 - val_accuracy: 0.7603
# Epoch 64/150
# 13/13 [==============================] - 5s 394ms/step - loss: 6.7772 - mae: 2.0017 - accuracy: 0.7787 - val_loss: 2.3579 - val_mae: 0.8182 - val_accuracy: 0.7589
# Epoch 65/150
# 13/13 [==============================] - 5s 393ms/step - loss: 6.3252 - mae: 1.9352 - accuracy: 0.7806 - val_loss: 4.1297 - val_mae: 1.4686 - val_accuracy: 0.7411
# Epoch 66/150
# 13/13 [==============================] - 5s 398ms/step - loss: 7.0662 - mae: 2.0541 - accuracy: 0.7874 - val_loss: 7.8542 - val_mae: 2.2545 - val_accuracy: 0.7560
# Epoch 67/150
# 13/13 [==============================] - 5s 395ms/step - loss: 7.4409 - mae: 2.1075 - accuracy: 0.7813 - val_loss: 5.5827 - val_mae: 1.8581 - val_accuracy: 0.7752
# Epoch 68/150
# 13/13 [==============================] - 5s 395ms/step - loss: 6.1047 - mae: 1.8961 - accuracy: 0.7851 - val_loss: 4.0472 - val_mae: 1.4649 - val_accuracy: 0.7433
# Epoch 69/150
# 13/13 [==============================] - 5s 399ms/step - loss: 6.2726 - mae: 1.9211 - accuracy: 0.7858 - val_loss: 2.8022 - val_mae: 0.9280 - val_accuracy: 0.7468
# Epoch 70/150
# 13/13 [==============================] - 5s 389ms/step - loss: 5.6439 - mae: 1.8216 - accuracy: 0.7991 - val_loss: 2.7844 - val_mae: 1.0128 - val_accuracy: 0.7709
# Epoch 71/150
# 13/13 [==============================] - 5s 388ms/step - loss: 5.2964 - mae: 1.7635 - accuracy: 0.7877 - val_loss: 3.4617 - val_mae: 1.3137 - val_accuracy: 0.7617
# Epoch 72/150
# 13/13 [==============================] - 5s 388ms/step - loss: 5.6174 - mae: 1.8226 - accuracy: 0.7865 - val_loss: 3.4656 - val_mae: 1.1773 - val_accuracy: 0.7589
# Epoch 73/150
# 13/13 [==============================] - 5s 386ms/step - loss: 5.5105 - mae: 1.8022 - accuracy: 0.7989 - val_loss: 2.3549 - val_mae: 0.7930 - val_accuracy: 0.7688
# Epoch 74/150
# 13/13 [==============================] - 5s 387ms/step - loss: 5.2330 - mae: 1.7525 - accuracy: 0.7998 - val_loss: 2.8965 - val_mae: 0.9846 - val_accuracy: 0.7511
# Epoch 75/150
# 13/13 [==============================] - 5s 387ms/step - loss: 5.8847 - mae: 1.8607 - accuracy: 0.8028 - val_loss: 2.4870 - val_mae: 0.7487 - val_accuracy: 0.7199
# Epoch 76/150
# 13/13 [==============================] - 5s 387ms/step - loss: 6.4034 - mae: 1.9477 - accuracy: 0.7968 - val_loss: 2.6615 - val_mae: 0.8501 - val_accuracy: 0.7745
# Epoch 77/150
# 13/13 [==============================] - 5s 387ms/step - loss: 5.1736 - mae: 1.7427 - accuracy: 0.8016 - val_loss: 2.4837 - val_mae: 0.7875 - val_accuracy: 0.7709
# Epoch 78/150
# 13/13 [==============================] - 5s 387ms/step - loss: 5.9980 - mae: 1.8760 - accuracy: 0.7932 - val_loss: 2.5066 - val_mae: 0.9396 - val_accuracy: 0.7610
# Epoch 79/150
# 13/13 [==============================] - 5s 391ms/step - loss: 5.3678 - mae: 1.7728 - accuracy: 0.8134 - val_loss: 2.9148 - val_mae: 1.0967 - val_accuracy: 0.7723
# Epoch 80/150
# 13/13 [==============================] - 5s 399ms/step - loss: 5.1471 - mae: 1.7370 - accuracy: 0.8131 - val_loss: 3.4831 - val_mae: 1.0246 - val_accuracy: 0.7688
# Epoch 81/150
# 13/13 [==============================] - 5s 396ms/step - loss: 5.0684 - mae: 1.7216 - accuracy: 0.8063 - val_loss: 3.4615 - val_mae: 1.2937 - val_accuracy: 0.7823
# Epoch 82/150
# 13/13 [==============================] - 5s 400ms/step - loss: 5.3865 - mae: 1.7864 - accuracy: 0.8030 - val_loss: 2.7801 - val_mae: 1.0150 - val_accuracy: 0.7688
# Epoch 83/150
# 13/13 [==============================] - 5s 392ms/step - loss: 6.4243 - mae: 1.9541 - accuracy: 0.8152 - val_loss: 2.2777 - val_mae: 0.7416 - val_accuracy: 0.8007
# Epoch 84/150
# 13/13 [==============================] - 5s 396ms/step - loss: 5.6529 - mae: 1.8189 - accuracy: 0.8126 - val_loss: 2.4114 - val_mae: 0.7533 - val_accuracy: 0.7560
# Epoch 85/150
# 13/13 [==============================] - 5s 395ms/step - loss: 5.0292 - mae: 1.7102 - accuracy: 0.8145 - val_loss: 4.3045 - val_mae: 1.6000 - val_accuracy: 0.7589
# Epoch 86/150
# 13/13 [==============================] - 5s 388ms/step - loss: 5.1408 - mae: 1.7407 - accuracy: 0.8152 - val_loss: 2.3255 - val_mae: 0.8001 - val_accuracy: 0.7723
# Epoch 87/150
# 13/13 [==============================] - 5s 391ms/step - loss: 4.7260 - mae: 1.6620 - accuracy: 0.8237 - val_loss: 2.5431 - val_mae: 0.8411 - val_accuracy: 0.7830
# Epoch 88/150
# 13/13 [==============================] - 5s 406ms/step - loss: 4.6559 - mae: 1.6486 - accuracy: 0.8179 - val_loss: 2.7367 - val_mae: 0.9255 - val_accuracy: 0.7809
# Epoch 89/150
# 13/13 [==============================] - 5s 399ms/step - loss: 4.9972 - mae: 1.7092 - accuracy: 0.8172 - val_loss: 2.7991 - val_mae: 1.0969 - val_accuracy: 0.7865
# Epoch 90/150
# 13/13 [==============================] - 5s 393ms/step - loss: 4.5343 - mae: 1.6317 - accuracy: 0.8230 - val_loss: 2.4563 - val_mae: 0.8665 - val_accuracy: 0.7915
# Epoch 91/150
# 13/13 [==============================] - 5s 391ms/step - loss: 4.5996 - mae: 1.6376 - accuracy: 0.8198 - val_loss: 2.4200 - val_mae: 0.9042 - val_accuracy: 0.7702
# Epoch 92/150
# 13/13 [==============================] - 5s 391ms/step - loss: 4.6915 - mae: 1.6557 - accuracy: 0.8262 - val_loss: 2.8304 - val_mae: 0.8171 - val_accuracy: 0.7397
# Epoch 93/150
# 13/13 [==============================] - 5s 389ms/step - loss: 4.3752 - mae: 1.5955 - accuracy: 0.8280 - val_loss: 2.7214 - val_mae: 0.8682 - val_accuracy: 0.7801
# Epoch 94/150
# 13/13 [==============================] - 5s 391ms/step - loss: 4.3590 - mae: 1.5872 - accuracy: 0.8253 - val_loss: 3.1242 - val_mae: 1.0557 - val_accuracy: 0.7915
# Epoch 95/150
# 13/13 [==============================] - 5s 403ms/step - loss: 5.6611 - mae: 1.8194 - accuracy: 0.8232 - val_loss: 2.8758 - val_mae: 1.1339 - val_accuracy: 0.7794
# Epoch 96/150
# 13/13 [==============================] - 5s 402ms/step - loss: 4.5616 - mae: 1.6318 - accuracy: 0.8315 - val_loss: 4.1453 - val_mae: 1.5067 - val_accuracy: 0.7844
# Epoch 97/150
# 13/13 [==============================] - 5s 418ms/step - loss: 6.7368 - mae: 2.0054 - accuracy: 0.8303 - val_loss: 8.4542 - val_mae: 2.4664 - val_accuracy: 0.7610
# Epoch 98/150
# 13/13 [==============================] - 5s 405ms/step - loss: 5.4919 - mae: 1.7877 - accuracy: 0.8232 - val_loss: 3.2100 - val_mae: 1.1565 - val_accuracy: 0.7674
# Epoch 99/150
# 13/13 [==============================] - 5s 408ms/step - loss: 4.6913 - mae: 1.6495 - accuracy: 0.8243 - val_loss: 5.2954 - val_mae: 1.8523 - val_accuracy: 0.7801
# Epoch 100/150
# 13/13 [==============================] - 5s 386ms/step - loss: 4.5735 - mae: 1.6287 - accuracy: 0.8315 - val_loss: 3.2387 - val_mae: 1.2596 - val_accuracy: 0.7745
# Epoch 101/150
# 13/13 [==============================] - 5s 387ms/step - loss: 4.3548 - mae: 1.5904 - accuracy: 0.8319 - val_loss: 2.6033 - val_mae: 0.9661 - val_accuracy: 0.7723
# Epoch 102/150
# 13/13 [==============================] - 5s 387ms/step - loss: 4.6010 - mae: 1.6337 - accuracy: 0.8418 - val_loss: 3.1407 - val_mae: 1.0548 - val_accuracy: 0.7617
# Epoch 103/150
# 13/13 [==============================] - 5s 404ms/step - loss: 4.4491 - mae: 1.6056 - accuracy: 0.8349 - val_loss: 3.1923 - val_mae: 1.2622 - val_accuracy: 0.7702
# Epoch 104/150
# 13/13 [==============================] - 5s 393ms/step - loss: 4.2585 - mae: 1.5747 - accuracy: 0.8466 - val_loss: 2.3870 - val_mae: 0.7592 - val_accuracy: 0.7844
# Epoch 105/150
# 13/13 [==============================] - 5s 394ms/step - loss: 5.1653 - mae: 1.7369 - accuracy: 0.8367 - val_loss: 4.1415 - val_mae: 1.5556 - val_accuracy: 0.7915
# Epoch 106/150
# 13/13 [==============================] - 5s 398ms/step - loss: 6.1032 - mae: 1.8960 - accuracy: 0.8459 - val_loss: 4.9709 - val_mae: 1.6783 - val_accuracy: 0.7809
# Epoch 107/150
# 13/13 [==============================] - 5s 400ms/step - loss: 5.7594 - mae: 1.8300 - accuracy: 0.8289 - val_loss: 4.7611 - val_mae: 1.3151 - val_accuracy: 0.7645
# Epoch 108/150
# 13/13 [==============================] - 5s 389ms/step - loss: 4.6904 - mae: 1.6461 - accuracy: 0.8429 - val_loss: 6.8649 - val_mae: 2.1751 - val_accuracy: 0.7965
# Epoch 109/150
# 13/13 [==============================] - 5s 386ms/step - loss: 4.5467 - mae: 1.6243 - accuracy: 0.8333 - val_loss: 2.5971 - val_mae: 0.8013 - val_accuracy: 0.7603
# Epoch 110/150
# 13/13 [==============================] - 5s 387ms/step - loss: 4.8729 - mae: 1.6786 - accuracy: 0.8425 - val_loss: 7.7374 - val_mae: 2.3785 - val_accuracy: 0.7617
# Epoch 111/150
# 13/13 [==============================] - 5s 387ms/step - loss: 5.0084 - mae: 1.7033 - accuracy: 0.8468 - val_loss: 2.9171 - val_mae: 1.0803 - val_accuracy: 0.7929
# Epoch 112/150
# 13/13 [==============================] - 5s 393ms/step - loss: 4.1419 - mae: 1.5511 - accuracy: 0.8383 - val_loss: 3.9840 - val_mae: 1.4506 - val_accuracy: 0.7539
# Epoch 113/150
# 13/13 [==============================] - 5s 388ms/step - loss: 5.0782 - mae: 1.7280 - accuracy: 0.8441 - val_loss: 3.2686 - val_mae: 0.9678 - val_accuracy: 0.7887
# Epoch 114/150
# 13/13 [==============================] - 5s 389ms/step - loss: 4.5363 - mae: 1.6158 - accuracy: 0.8441 - val_loss: 2.8650 - val_mae: 0.9822 - val_accuracy: 0.7787
# Epoch 115/150
# 13/13 [==============================] - 5s 389ms/step - loss: 4.3632 - mae: 1.5862 - accuracy: 0.8512 - val_loss: 4.9281 - val_mae: 1.7831 - val_accuracy: 0.7794
# Epoch 116/150
# 13/13 [==============================] - 5s 404ms/step - loss: 5.0591 - mae: 1.7146 - accuracy: 0.8431 - val_loss: 2.2494 - val_mae: 0.6704 - val_accuracy: 0.7589
# Epoch 117/150
# 13/13 [==============================] - 5s 392ms/step - loss: 4.6829 - mae: 1.6483 - accuracy: 0.8354 - val_loss: 2.5911 - val_mae: 0.9678 - val_accuracy: 0.8050
# Epoch 118/150
# 13/13 [==============================] - 5s 386ms/step - loss: 4.6450 - mae: 1.6367 - accuracy: 0.8480 - val_loss: 2.7443 - val_mae: 1.0008 - val_accuracy: 0.7702
# Epoch 119/150
# 13/13 [==============================] - 5s 398ms/step - loss: 5.0377 - mae: 1.7049 - accuracy: 0.8470 - val_loss: 4.8885 - val_mae: 1.7704 - val_accuracy: 0.7688
# Epoch 120/150
# 13/13 [==============================] - 5s 389ms/step - loss: 3.9031 - mae: 1.5008 - accuracy: 0.8516 - val_loss: 2.4899 - val_mae: 0.7762 - val_accuracy: 0.7695
# Epoch 121/150
# 13/13 [==============================] - 5s 396ms/step - loss: 4.8703 - mae: 1.6823 - accuracy: 0.8571 - val_loss: 4.2219 - val_mae: 1.5713 - val_accuracy: 0.7603
# Epoch 122/150
# 13/13 [==============================] - 5s 387ms/step - loss: 4.6429 - mae: 1.6387 - accuracy: 0.8544 - val_loss: 3.6831 - val_mae: 1.0941 - val_accuracy: 0.7695
# Epoch 123/150
# 13/13 [==============================] - 5s 386ms/step - loss: 4.0421 - mae: 1.5237 - accuracy: 0.8500 - val_loss: 2.8184 - val_mae: 1.0685 - val_accuracy: 0.7851
# Epoch 124/150
# 13/13 [==============================] - 5s 386ms/step - loss: 3.9137 - mae: 1.5031 - accuracy: 0.8500 - val_loss: 2.2765 - val_mae: 0.7766 - val_accuracy: 0.7929
# Epoch 125/150
# 13/13 [==============================] - 5s 417ms/step - loss: 3.9266 - mae: 1.5084 - accuracy: 0.8548 - val_loss: 2.5606 - val_mae: 0.8463 - val_accuracy: 0.7695
# Epoch 126/150
# 13/13 [==============================] - 5s 417ms/step - loss: 3.9988 - mae: 1.5202 - accuracy: 0.8590 - val_loss: 2.5590 - val_mae: 1.0196 - val_accuracy: 0.7645
# Epoch 127/150
# 13/13 [==============================] - 5s 397ms/step - loss: 4.3903 - mae: 1.6028 - accuracy: 0.8581 - val_loss: 3.3607 - val_mae: 1.2146 - val_accuracy: 0.7660
# Epoch 128/150
# 13/13 [==============================] - 5s 388ms/step - loss: 3.8609 - mae: 1.4922 - accuracy: 0.8656 - val_loss: 2.2946 - val_mae: 0.7000 - val_accuracy: 0.7979
# Epoch 129/150
# 13/13 [==============================] - 5s 413ms/step - loss: 3.7444 - mae: 1.4621 - accuracy: 0.8647 - val_loss: 2.7027 - val_mae: 0.8445 - val_accuracy: 0.7759
# Epoch 130/150
# 13/13 [==============================] - 5s 414ms/step - loss: 4.5627 - mae: 1.6303 - accuracy: 0.8590 - val_loss: 3.8649 - val_mae: 1.4516 - val_accuracy: 0.7738
# Epoch 131/150
# 13/13 [==============================] - 5s 388ms/step - loss: 4.0166 - mae: 1.5239 - accuracy: 0.8615 - val_loss: 2.5339 - val_mae: 0.7736 - val_accuracy: 0.7830
# Epoch 132/150
# 13/13 [==============================] - 5s 403ms/step - loss: 4.2266 - mae: 1.5662 - accuracy: 0.8551 - val_loss: 2.5429 - val_mae: 0.8625 - val_accuracy: 0.7851
# Epoch 133/150
# 13/13 [==============================] - 5s 393ms/step - loss: 4.2297 - mae: 1.5578 - accuracy: 0.8553 - val_loss: 3.9678 - val_mae: 1.4331 - val_accuracy: 0.7759
# Epoch 134/150
# 13/13 [==============================] - 5s 395ms/step - loss: 3.9411 - mae: 1.5011 - accuracy: 0.8603 - val_loss: 2.7203 - val_mae: 0.9067 - val_accuracy: 0.7773
# Epoch 135/150
# 13/13 [==============================] - 5s 387ms/step - loss: 4.1208 - mae: 1.5363 - accuracy: 0.8624 - val_loss: 4.1366 - val_mae: 1.4088 - val_accuracy: 0.7738
# Epoch 136/150
# 13/13 [==============================] - 5s 390ms/step - loss: 5.0530 - mae: 1.7174 - accuracy: 0.8583 - val_loss: 3.7539 - val_mae: 1.2543 - val_accuracy: 0.7745
# Epoch 137/150
# 13/13 [==============================] - 5s 392ms/step - loss: 4.4987 - mae: 1.6077 - accuracy: 0.8555 - val_loss: 3.9648 - val_mae: 1.4570 - val_accuracy: 0.7766
# Epoch 138/150
# 13/13 [==============================] - 5s 397ms/step - loss: 3.9419 - mae: 1.5111 - accuracy: 0.8649 - val_loss: 2.6955 - val_mae: 0.8200 - val_accuracy: 0.7660
# Epoch 139/150
# 13/13 [==============================] - 5s 386ms/step - loss: 3.8419 - mae: 1.4885 - accuracy: 0.8601 - val_loss: 2.3773 - val_mae: 0.7865 - val_accuracy: 0.7950
# Epoch 140/150
# 13/13 [==============================] - 5s 391ms/step - loss: 3.8050 - mae: 1.4729 - accuracy: 0.8635 - val_loss: 6.0970 - val_mae: 1.9933 - val_accuracy: 0.7730
# Epoch 141/150
# 13/13 [==============================] - 5s 390ms/step - loss: 5.7985 - mae: 1.8575 - accuracy: 0.8658 - val_loss: 5.2743 - val_mae: 1.7490 - val_accuracy: 0.7617
# Epoch 142/150
# 13/13 [==============================] - 5s 397ms/step - loss: 6.0789 - mae: 1.8764 - accuracy: 0.8555 - val_loss: 12.1617 - val_mae: 3.0254 - val_accuracy: 0.7206
# Epoch 143/150
# 13/13 [==============================] - 5s 391ms/step - loss: 5.2369 - mae: 1.7367 - accuracy: 0.8565 - val_loss: 2.2339 - val_mae: 0.7332 - val_accuracy: 0.7965
# Epoch 144/150
# 13/13 [==============================] - 5s 393ms/step - loss: 4.2873 - mae: 1.5651 - accuracy: 0.8509 - val_loss: 3.5893 - val_mae: 1.3795 - val_accuracy: 0.7844
# Epoch 145/150
# 13/13 [==============================] - 5s 401ms/step - loss: 3.6878 - mae: 1.4470 - accuracy: 0.8636 - val_loss: 2.5776 - val_mae: 0.9048 - val_accuracy: 0.7915
# Epoch 146/150
# 13/13 [==============================] - 5s 392ms/step - loss: 3.7162 - mae: 1.4528 - accuracy: 0.8624 - val_loss: 2.6182 - val_mae: 1.0116 - val_accuracy: 0.7887
# Epoch 147/150
# 13/13 [==============================] - 5s 389ms/step - loss: 3.7270 - mae: 1.4660 - accuracy: 0.8638 - val_loss: 3.0695 - val_mae: 1.2160 - val_accuracy: 0.7816
# Epoch 148/150
# 13/13 [==============================] - 5s 398ms/step - loss: 3.6762 - mae: 1.4502 - accuracy: 0.8750 - val_loss: 2.3781 - val_mae: 0.7884 - val_accuracy: 0.7787
# Epoch 149/150
# 13/13 [==============================] - 5s 396ms/step - loss: 3.5288 - mae: 1.4216 - accuracy: 0.8728 - val_loss: 3.8303 - val_mae: 1.4015 - val_accuracy: 0.7787
# Epoch 150/150
# 13/13 [==============================] - 5s 392ms/step - loss: 3.7758 - mae: 1.4727 - accuracy: 0.8652 - val_loss: 3.0111 - val_mae: 0.9060 - val_accuracy: 0.7773
# Duration: 0:13:14.516996

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc, acc = model.evaluate(X_train,y_train, verbose=2)
# Out:
# 221/221 - 3s - loss: 1.4214 - mae: 0.7172 - accuracy: 0.8807

# %%
arc = '6block_2FC'
subname = '{}_epochs_{}_'.format(arc, epochs)
model_name = "data/models/"+subname+strftime("%Y-%m-%d_%H-%M-%S")+".keras"
model.save(model_name)

# %%
model_name
# Out:
# 'data/models/6block_2FC_epochs_150_2020-12-05_01-17-15.keras'

# %%
# model_name = "model_simple_nn_2020-11-13_06-57-10.keras"
model = keras.models.load_model(model_name)

# %%
keras.utils.plot_model(model, show_shapes=True)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
images = []

test_data = pd.read_csv('data/test.csv') 
for idx, sample in test_data.iterrows():
    image = np.array(sample['Image'].split(' '), dtype=int)
    image = np.reshape(image, (96,96,1))
    images.append(image)
X_predict = np.array(images)

# %% [markdown]
# # Make Predictions

# %%
Id_data = pd.read_csv('data/IdLookupTable.csv') 

test_preds = model.predict(X_predict)
test_preds[test_preds > 96] = 96

image_id = list(Id_data["ImageId"]-1)
mark_names = list(Id_data['FeatureName'])
mark_id = [mark_names.index(x) for x in mark_names]

req_predictions = [test_preds[x,y] for x,y in zip(image_id,mark_id)]

rowid = pd.Series(Id_data['RowId'], name = 'RowId')
loc = pd.Series(req_predictions, name = 'Location')
submission = pd.concat([rowid, loc], axis = 1)
submission.to_csv('data/{}submission.csv'.format(subname),index = False)

# %%
'data/{}submission.csv'.format(subname)
# Out:
# 'data/6block_2FC_epochs_150_submission.csv'
